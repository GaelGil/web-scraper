# %%
import pandas as pd

# %%
data = pd.read_csv("data/Registered_Business_Locations_-_San_Francisco.csv")
# Out:
# /Users/GaelGil/Desktop/GitRepos/Sneaker-Scraper/env/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3051: DtypeWarning: Columns (12,13,14,15,21,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head(10)
# Out:
#       Location Id  Business Account Number     Ownership Name  \
# 0  1103593-08-161                  1049564  Anjan Rajbhandari
# 1  1218784-04-191                  1100756      Luisa Alberto
# 2  1223199-05-191                  1102424       Sunrun, Inc.
# 3  1220748-05-191                  1101579    Felix Hernandez
# 4  1135452-02-171                  1065102          Tirta Llc
# 5  1157686-08-171                  1074591           Alice Ho
# 6  1131829-01-171                  1063275        Outwork Inc
# 7  1221744-05-191                  1101933      Ava Tours Llc
# 8  1222244-05-191                  1102118    Evgo Ride Share
# 9  1230322-08-191                  1105226         Elka Duran
#
#                    DBA Name     Street Address           City State  \
# 0                      Uber   28134 Harvey Ave        Hayward    CA
# 1              High Five Sf        467 14th St  San Francisco    CA
# 2               Sunrun, Inc      595 Market St  San Francisco    CA
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255033 entries, 0 to 255032
# Data columns (total 26 columns):
# Location Id                            255033 non-null object
# Business Account Number                255033 non-null int64
# Ownership Name                         255033 non-null object
# DBA Name                               255033 non-null object
# Street Address                         255029 non-null object
# City                                   254842 non-null object
# State                                  254417 non-null object
# Source Zipcode                         254766 non-null float64
# Business Start Date                    255032 non-null object
# Business End Date                      101828 non-null object
# Location Start Date                    255032 non-null object
# Location End Date                      127446 non-null object
# Mail Address                           158578 non-null object
# ...

# %%
data.astype({'Business Location': 'object'}).dtypes
data.astype({'Business Location': 'object'}).dtypes
data.astype({'Business Location': 'object'}).dtypes
data.astype({'Business Location': 'object'}).dtypes
data.astype({'Business Location': 'object'}).dtypes
# Out:
# Location Id                             object
# Business Account Number                  int64
# Ownership Name                          object
# DBA Name                                object
# Street Address                          object
# City                                    object
# State                                   object
# Source Zipcode                         float64
# Business Start Date                     object
# Business End Date                       object
# Location Start Date                     object
# Location End Date                       object
# Mail Address                            object
# Mail City                               object
# Mail Zipcode                            object
# Mail State                              object
# NAICS Code                              object
# NAICS Code Description                  object
# Parking Tax                               bool
# Transient Occupancy Tax                   bool
# ...

# %%
data['Business Location']
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 255028    NaN
# 255029    NaN
# 255030    NaN
# 255031    NaN
# 255032    NaN
# Name: Business Location, Length: 255033, dtype: object

# %%
data.loc[40009]
# Out:
# Location Id                                            0454420-01-999
# Business Account Number                                        454420
# Ownership Name                         Acrf Construction Services Inc
# DBA Name                               Acrf Construction Services Inc
# Street Address                                       4929 Sunshine Ln
# City                                                       Sacramento
# State                                                              CA
# Source Zipcode                                                  95841
# Business Start Date                                        11/30/2010
# Business End Date                                          04/20/2015
# Location Start Date                                        11/30/2010
# Location End Date                                          04/20/2015
# Mail Address                                                      NaN
# ...
